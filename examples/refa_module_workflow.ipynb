# %% [markdown]
# 💡The `refa` module offers necessary classes to build a complete techno-economic analysis of different capacity upgrade options.
# All models are imported assuming a system of units, which can be changed at the `config.toml` file.

# %%
from refa import (
    LineDesign, Conductor, Line, Rebuild, Reconductoring, VoltageUpgrade, HVDC, Existing, Analysis
)

# %% [markdown]
# ⚠️ Following example usage is provided in both `metric` and `imperial` unit systems. Make sure to comment/uncomment the appropriate part of the code.
# Note that all objects are saved internally using the `metric` unit system. Therefore, it's recommended to use `get_parameter(param_name)` and other setter/getter functions to interact with objects in `imperial` unit system (object constructors are also available in `imperial` unit system).

# %% [markdown]
# 💡Default constuctors are included in `refa.defaults` to illustrate how different inputs can be entered.

# %%
from refa.defaults import (
    default_economics,
    default_clear_environment, default_clear_environment_imperial,
    default_conductor, default_conductor_imperial,
    default_structure_config_ac, default_structure_config_ac_imperial,
    default_structure_config_dc, default_structure_config_dc_imperial
)

# # metric
# my_conductor = default_conductor()
# my_environment = default_clear_environment()
# my_structure_config_ac = default_structure_config_ac()
# my_structure_config_dc = default_structure_config_dc()

# imperial
my_conductor = default_conductor_imperial()
my_environment = default_clear_environment_imperial()
my_structure_config_ac = default_structure_config_ac_imperial()
my_structure_config_dc = default_structure_config_dc_imperial()

my_economics = default_economics()

# %% [markdown]
# 💡Standard NESC 250B rule loading profiles are provided at `refa.standards`. The `Loading` class can be used to create custom loading profiles.

# %%
from refa.standards import nesc_250b_heavy, nesc_250b_heavy_imperial

# my_loading = nesc_250b_heavy()
# print(my_loading)

my_loading = nesc_250b_heavy_imperial()
print(my_loading.get_parameter_info('pressure'))
print(my_loading.get_parameter('wind_ice_temperature'))

# %% [markdown]
# 💡To create a `Line`, you should build a `LineDesign` and a `Conductor`. Typical conductor sizes can be found in `refa.defaults`. The code examples below illustrate possibility to use constructors different unit systems, where the unit of a parameter (when applicable) is appended to the displayed name.

# %%
# imperial
from refa.defaults import default_conductor_imperial, acsr_795_0_drake, acss_795_0_cuckoo, acss_1033_5_ortolan
from refa.system_parameters import CF

line_design1 = LineDesign(
    environment=my_environment,
    nbr_circuits=1,
    nbr_bundles=3,
    nbr_conds_per_bundle=1,
    length_mile=10,
    avg_span_ft=250,
    max_span_ft=300
)
line_design2 = LineDesign(
    environment=my_environment,
    nbr_circuits=1,
    nbr_bundles=3,
    nbr_conds_per_bundle=1,
    length_mile=30,
    avg_span_ft=300,
    max_span_ft=350
)
print("Line design -> ", line_design1)

conductor = Conductor(
        type='ACSR',
        code='266.8_PARTRIDGE',
        area_kcmil=157.0 * CF.mm2_to_kcmil,
        diameter_in=16.0 * CF.mm_to_in,
        weight_lbs_per_kft=5.36 * CF.n_per_m_to_lbs_per_kft,
        conductor_rts_kip=50.26 * CF.kn_to_kip,
        cost_dol_per_kft=735.0 * CF.ft_to_m,
        installation_dol_per_kft=1027.0 * CF.ft_to_m,
        accessories_dol_per_kft=263.0 * CF.ft_to_m,
        temp_dc_f=CF.c_to_f(40),
        temp_low_f=CF.c_to_f(45),
        temp_high_f=CF.c_to_f(160),
        max_temperature_f=CF.c_to_f(180),
        res_dc_ohm_per_mile=0.000209 * CF.mile_to_m,
        res_low_ohm_per_mile=0.000209 * CF.mile_to_m,
        res_high_ohm_per_mile=0.000256 * CF.mile_to_m,
        elastic_modulus_ksi=75.5 * CF.gpa_to_ksi,
        coeff_thermal_expan_per_f=1.92e-05 * 5 / 9,
        emissivity=0.5,
        solar_absorptivity=0.5
)
print("Conductor using constructor -> ", conductor)

conductor1 = default_conductor_imperial()
print("Conductor from default database -> ", conductor1)

conductor2 = acsr_795_0_drake()
conductor3 = acss_1033_5_ortolan()

# %% [markdown]
# ⚠️ Different system of units `metric` (need to update `config.toml` file, and reload all models of the refa module).

# %%
# # metric
# from refa.defaults import acsr_795_0_drake, acss_795_0_cuckoo, acss_1033_5_ortolan, load_conductors_from_csv

# line_design1 = LineDesign(
#     environment=my_environment,
#     nbr_circuits=1,
#     nbr_bundles=3,
#     nbr_conds_per_bundle=1,
#     length_km=10,
#     avg_span_m=250,
#     max_span_m=300
# )
# line_design2 = LineDesign(
#     environment=my_environment,
#     nbr_circuits=1,
#     nbr_bundles=3,
#     nbr_conds_per_bundle=1,
#     length_km=30,
#     avg_span_m=300,
#     max_span_m=300
# )
# print("Line design -> ", line_design1)

# conductor = Conductor(
#         type='ACSR',
#         code='266.8_PARTRIDGE',
#         area_mm2=157.0,
#         diameter_mm=16.0,
#         weight_n_per_m=5.36,
#         conductor_rts_kn=50.26,
#         cost_dol_per_km=735.0,
#         installation_dol_per_km=1027.0,
#         accessories_dol_per_km=263.0,
#         temp_dc_c=20.0,
#         temp_low_c=25.0,
#         temp_high_c=75.0,
#         max_temperature_c=100.0,
#         res_dc_ohm_per_m=0.000209,
#         res_low_ohm_per_m=0.000209,
#         res_high_ohm_per_m=0.000256,
#         elastic_modulus_gpa=75.5,
#         coeff_thermal_expan_per_c=1.92e-05,
#         emissivity=0.5,
#         solar_absorptivity=0.5
# )
# print("Conductor using constructor -> ", conductor)

# conductor1 = acss_795_0_cuckoo()
# conductor2 = acsr_795_0_drake()
# conductor3 = acss_1033_5_ortolan()
# print("Conductor from default database -> ", conductor1)

# conductors = load_conductors_from_csv('conductors_test.csv')
# print("Conductor from csv file -> ", conductors.acsr_477_0_pelican())

# %% [markdown]
# 💡Then, a line can be created either using `Line` constructor, or directly summing a `LineDesign` and a `Conductor`.

# %%
line1 = Line(line_design=line_design1, conductor=acss_795_0_cuckoo())
line2 = line_design2 + conductor2
line3 = conductor3 + line_design1

print(line1)

# %% [markdown]
# 💡Different technical calculations can be conducted using a `Line` object.

# %%
temperature_from_current = line1.temperature_at_current(current_a=1400) 
resistance_from_current = line1.resistance_at_current(current_a=1400)
temperature_from_p_and_v = line1.temperature_at_current(power_mw=550, voltage_kv=345)
resistance_from_p_and_v = line1.resistance_at_current(power_mw=550, voltage_kv=345)
print(f"Conductor temperature when current is provided -> {temperature_from_current}")
print(f"Conductor resistance when current is provided -> {resistance_from_current}")
print(f"Conductor temperature when power and voltage are provided -> {temperature_from_p_and_v}")
print(f"Conductor resistance when power and voltage are provided -> {resistance_from_p_and_v}")

ampacity = line1.ampacity_at_environment()
print(f"Ampacity -> {ampacity}")

sag_from_peak_current = line1.sag_at_current(current_a=1400, initial_tension_percentage=0.2)
sag_from_power_and_voltage = line1.sag_at_power_and_voltage(power_mw=500, voltage_kv=230, initial_tension_percentage=0.2)
sag_from_conductor_temperature = line1.sag_at_temperature(temp_at_current_c=85, initial_tension_percentage=0.2)
sag_from_loading_profile = line1.sag_at_loading(loading_conditions=my_loading, initial_tension_percentage=0.2)
print(f"Sag when peak current is provided -> {sag_from_peak_current}")
print(f"Sag when conductor temperature is provided -> {sag_from_conductor_temperature}")
print(f"Sag when a wind/ice loading profile is provided -> {sag_from_loading_profile}")

corona_inception_voltage = line1.corona_inception_voltage(structure_config=my_structure_config_ac) 
corona_voltage_gradient = line1.corona_voltage_gradient(structure_config=my_structure_config_ac)
print(f"Corona Inception voltage -> {corona_inception_voltage} kV")
print(f"Corona voltage gradient -> {corona_voltage_gradient} kV/cm")

# %% [markdown]
# 💡Also, losses and congestion of a given `Line` can be calculated using available functions.

# %%
annual_resistive_line_losses_from_current = line1.resistive_line_losses(current_a=1400, load_factor=0.6)
annual_resistive_line_losses_with_congestion = \
    line1.resistive_line_losses_considering_congestion(power_mw=550, voltage_kv=230, load_factor=0.6)
print(f"Resistive line losses when current is provided -> {annual_resistive_line_losses_from_current} MWh/m")
print(f"Resistive line losses when power is provided -> {annual_resistive_line_losses_with_congestion} MWh/m")

annual_corona_discharge_losses = line1.corona_discharge_losses(
    voltage_kv=230, load_factor=0.6, structure_config=my_structure_config_ac
)
print(f"Corona discharge losses -> {annual_corona_discharge_losses} MWh/m")

annual_corona_discharge_losses_dc = line1.corona_discharge_losses(
    voltage_kv=230, load_factor=0.6, structure_config=my_structure_config_dc, is_hvdc=True
)
print(f"Corona discharge losses (DC line) -> {annual_corona_discharge_losses_dc} MWh/m")

congestion_from_current = line1.congestion(current_a=1500, voltage_kv=230)
congestion_from_power = line1.congestion(power_mw=700, voltage_kv=230)
print(f"Congestion when current is provided -> {congestion_from_current} MW")
print(f"Congestion when power is provided -> {congestion_from_power} MW")

# %% [markdown]
# 💡The overall technical performance of a `Line` can be calculated in a single function call. The basic usage calculates only ampacity and sag when current or 'power+voltage' are provided; then includes losses if load_factor is provided, and corona discharge if structure_config is provided.

# %%
technical_perf_from_current = line1.overall_technical_performance(current_a=1500)
print(f"Overall performance when only current is provided -> {technical_perf_from_current}")

technical_perf_from_power_and_voltage = line1.overall_technical_performance(
    power_mw=500, voltage_kv=230
)
print(f"Overall performance when power and voltage are provided -> {technical_perf_from_power_and_voltage}")

technical_perf_including_losses = line1.overall_technical_performance(
    current_a=1500, load_factor=0.6
)
print(f"Overall performance including losses -> {technical_perf_including_losses}")

technical_perf_including_losses_and_corona = line1.overall_technical_performance(
    current_a=1500, voltage_kv=230, load_factor=0.6, structure_config=my_structure_config_ac
)
print(f"Overall performance including corona discharge -> {technical_perf_including_losses_and_corona}")

# %% [markdown]
# 💡An object `Line` allows to check for feasibility in terms of ampacity, sag, and corona discharge effect, where a function is provided for each of these technical constraints.

# %%
# line1.is_ampacity_feasible(current_a=1172)
# line1.is_ampacity_feasible(power_mw=700, voltage_kv=345) 

# line1.is_sag_feasible(current_a=1300, max_sag_m=10, initial_tension_percentage=0.3)

line1.is_corona_feasible(structure_config=my_structure_config_ac, voltage_kv=345)

# %% [markdown]
# 💡Different types of projects can be created using `a LineDesign + a list of Conductor objects` or `a list of Line Objects`.

# %%
rebuild_prj = Rebuild(
    conductor_list=[acsr_795_0_drake(), acss_795_0_cuckoo(), acss_1033_5_ortolan()], 
    line_design=line_design2,
    economics=my_economics,
    power_mw=250,
    voltage_kv=115,
    structure_config=my_structure_config_ac
)
reconductoring_prj = Reconductoring(
    line_list=[line1, line2], 
    economics=my_economics,
    power_mw=250,
    voltage_kv=115,
    structure_remaining_life=25
)
voltageupgrade_prj = VoltageUpgrade(
    line_list=[line2, line1], 
    economics=my_economics,
    power_mw=250,
    voltage_kv=230, 
    structure_remaining_life=0, 
    conductor_remaining_life=0,
    cost_substations_upgrade_dol=2000000  
)
hvdc_prj = HVDC(
    line_list=[line3, line2], 
    economics=my_economics,
    power_mw=250,
    voltage_kv=200, 
    structure_remaining_life=0, 
    conductor_remaining_life=0, 
    cost_converters_dol=3000000,
    nbr_dc_poles_per_circuit=2,
    structure_config=my_structure_config_dc
)
existing_prj = Existing(
    line_list=[line1], 
    economics=my_economics,
    power_mw=250,
    voltage_kv=115,
    structure_remaining_life=25,
    conductor_remaining_life=15
)

# %% [markdown]
# 💡Each project can use internal functions to calculate different costs. By default, the cumulative net-present value of costs (NPC) at `year=time_horizon-1` is reported. You can get the cumulative NPC for all years by setting the function argument `report_all_years=True`.

# %%
# rebuild_prj.total_costs(time_horizon=65)
# rebuild_prj.total_costs(time_horizon=65, report_all_years=True)
# rebuild_prj.total_costs_including_losses(time_horizon=65, load_factor=0.6)
# rebuild_prj.structure_costs(time_horizon=65)
# rebuild_prj.conductor_costs(time_horizon=65)
# rebuild_prj.losses_costs(time_horizon=65, load_factor=0.6)

reconductoring_prj.total_costs(time_horizon=65)
# reconductoring_prj.total_costs_including_losses(time_horizon=65, load_factor=0.6)
# reconductoring_prj.structure_costs(time_horizon=65)
# reconductoring_prj.conductor_costs(time_horizon=65)
# reconductoring_prj.losses_costs(time_horizon=65, load_factor=0.6)
# reconductoring_prj.congestion_costs(time_horizon=65)

# voltageupgrade_prj.total_costs(time_horizon=70)
# hvdc_prj.total_costs(time_horizon=70)

# %% [markdown]
# 💡`VoltageUpgrade` and `HVDC` projects contain costs that are not present in other types of projects. These costs of substation, transformer, or converter modifications are required by `VoltageUpgrade` and `HVDC` object constructors. These costs are currently added to the upfront capital cost, and can be updated as follows.

# %%
voltageupgrade_prj.cost_substations_upgrade_dol = 1000000
hvdc_prj.cost_converters_dol = 2000000

# %% [markdown]
# 💡Multiple projects can be compared using an object `Analysis` based on total net-present value of cost, or marginal costs of structures, conductors, losses, and congestion.
# By default, each line in a project is checked for feasibility in terms of ampacity (if `select_ampacity_feasible=True`), sag (if `select_sag_feasible=True`), and corona (if `select_corona_feasible=True`). This feasibility check can be deactivated by setting `select_...` attributes of project objects to `False`.

# %%
refa = Analysis(project_list=[
    rebuild_prj, reconductoring_prj, voltageupgrade_prj, hvdc_prj, existing_prj
    ])
refa.total_costs_of_projects(time_horizon=70)
# refa.total_costs_of_projects_including_losses(time_horizon=70, load_factor=0.6)

# refa.structure_costs_of_projects(time_horizon=70)
# refa.conductor_costs_of_projects(time_horizon=70, select_feasible=False)
# refa.losses_costs_of_projects(time_horizon=70, load_factor=0.6)
# refa.congestion_costs_of_projects(time_horizon=70)

# %% [markdown]
# Setters/Getter

# %%
print("Parameter info -> ", conductor1.get_parameter_info('area'))
print("Conductor - list of parameters -> ", conductor1.list_parameters())
print("Conductor - All parameters (values + default units) -> ", conductor1.get_all_parameters())
print("Conductor - All parameters (values + specified units) -> ", conductor1.get_all_parameters('metric'))
print("Conductor - One parameter -> ", conductor1.get_parameter('area'))
print("Conductor - One parameter with specific system -> ", conductor1.get_parameter('area', unit_system='metric'))
conductor1.set_parameter('area', 500)
print("Conductor - Set parameter -> ", conductor1.get_parameter('area'))
conductor1.set_parameter('area', 200, unit_system='metric')
print("Conductor - Set parameter with specific system-> ", conductor1.get_parameter('area'))
